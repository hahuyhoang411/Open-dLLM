# %% [markdown]
# # Open-dLLM Phase 3: Block Diffusion Training
#
# Train a block diffusion language model on FineWeb-Edu using Kaggle P100 GPU.
#
# - **Model**: ~148M params (depth=10), block_size=4
# - **Data**: FineWeb-Edu streaming (same as Phase 2)
# - **Key innovation**: Staircase attention mask — bidirectional within blocks, causal across blocks

# %%
# !pip install -q torch datasets transformers

# %%
# !git clone https://github.com/hahuyhoang411/Open-dLLM.git
# %cd Open-dLLM

# %%
import torch
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB" if torch.cuda.is_available() else "")

# %%
# !python 03_block_diffusion/block_dllm.py --train --depth 10 --block-size 4

# %%
# !python 03_block_diffusion/block_dllm.py --depth 10 --block-size 4 --prompt "The meaning of life is" --max-tokens 128

# %%
import shutil, os
os.makedirs('/kaggle/working/weights', exist_ok=True)
src = '03_block_diffusion/weights/block_dllm_d10_b4.pt'
if os.path.exists(src):
    shutil.copy(src, '/kaggle/working/weights/')
    print(f"Saved weights to /kaggle/working/weights/")
else:
    print(f"Weights not found at {src}")
