# %% [markdown]
# # Open-dLLM: DCLM CORE Evaluation
#
# Run the 22-task DCLM CORE benchmark on our dLLM and compare with GPT-2.
#
# - **dLLM**: ~35M params (depth=6), MC likelihood scoring
# - **GPT-2**: 124M params, standard AR scoring
# - **Score**: Centered accuracy (0 = random, 1 = perfect)

# %%
# Install dependencies
# !pip install -q torch jinja2 pyyaml transformers datasets tokenizers

# %%
# Clone the repo
# !git clone https://github.com/hahuyhoang411/Open-dLLM.git
# %cd Open-dLLM

# %%
# Check GPU
import torch
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
print(f"VRAM: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB" if torch.cuda.is_available() else "")

# %%
# Download or check for dLLM weights
import os
weights = '02_nano_dllm/weights/nano_dllm_d6.pt'
if not os.path.exists(weights):
    print("Weights not found. Training first (this takes ~1-2 hours on GPU)...")
    # !python 02_nano_dllm/nano_dllm.py --train --depth 6
else:
    print(f"Weights found at {weights}")

# %%
# Run dLLM evaluation (22 DCLM CORE tasks)
# !python eval/base_eval.py --model dllm --depth 6 --mc-num 64

# %%
# Run GPT-2 evaluation for comparison
# !python eval/base_eval.py --hf-model gpt2

# %%
# Save results
import shutil
os.makedirs('/kaggle/working/eval_results', exist_ok=True)
print("Evaluation complete. Results printed above.")
print("\nExpected scores:")
print("  GPT-2 (124M):  ~0.257 CORE")
print("  dLLM (35M):    ~0.00 CORE (small model, limited training)")
